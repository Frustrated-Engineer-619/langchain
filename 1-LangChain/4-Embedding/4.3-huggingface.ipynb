# %% [markdown]
# ### Embedding Techniques using HiggingFace

# %%
import os
from dotenv import load_dotenv
load_dotenv()

# %%
os.environ["HF_TOKEN"] = os.getenv("HF_TOKEN")

# %% [markdown]
# ### Sentence Transformers on Hugging Face
#
# Hugging face Sentence-transformers is a python farmework for state-of-the-art sentence, text and image embeddings. One of the embedding models is used in the HuggingFaceEmbedding class. we have also added an alias for SentenceTransformerEmbeddings for users who are more familiar with directly using that package.

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

# %%
text="this is a test documents"
query_result = embeddings.embed_query(text)
query_result

# %%
len(query_result)

# %%
doc_result = embeddings.embed_documents([text,"This is not a test document"])
doc_result[0]
